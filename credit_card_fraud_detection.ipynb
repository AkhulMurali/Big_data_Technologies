# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
plt.style.use('bmh')

# %%
df = pd.read_csv('/content/creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
df.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  11959.000000  11959.000000  11959.000000  11959.000000  11959.000000
# mean    8009.996822     -0.216230      0.277097      0.889505      0.282606
# std     6204.332248      1.583914      1.308884      1.331824      1.478162
# min        0.000000    -27.670569    -34.607649    -22.804686     -4.657545
# 25%     2542.000000     -0.978944     -0.261503      0.417186     -0.622456
# 50%     6662.000000     -0.340742      0.256346      0.951223      0.213029
# 75%    12382.000000      1.161273      0.883626      1.613678      1.159141
# max    20642.000000      1.960497      9.092123      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  11959.000000  11959.000000  11959.000000  11959.000000  11959.000000
# mean      -0.086585      0.139986     -0.121943     -0.048727      0.911579
# std        1.191776      1.306285      1.153899      1.246823      1.192349
# min      -32.092129    -23.496714    -26.548144    -23.632502     -7.175097
# 25%       -0.688114     -0.622521     -0.591335     -0.185243      0.196741
# 50%       -0.183847     -0.146903     -0.094876      0.013616      0.894911
# 75%        0.346298      0.508432      0.431657      0.267560      1.589120
# max       34.099309     21.393069     34.303177      5.499963     10.392889
#
#        ...           V21           V22           V23           V24  \
# count  ...  11958.000000  11958.000000  11958.000000  11958.000000
# mean   ...     -0.061474     -0.153850     -0.033709      0.017113
# std    ...      0.918705      0.626631      0.505355      0.591394
# min    ...    -11.468435     -8.593642    -19.254328     -2.512377
# 25%    ...     -0.268151     -0.543613     -0.171833     -0.333251
# 50%    ...     -0.130062     -0.124900     -0.044299      0.072099
# 75%    ...      0.021687      0.234029      0.075686      0.401798
# max    ...     22.614889      4.534454     13.876221      3.200201
#
#                 V25           V26           V27           V28        Amount  \
# count  11958.000000  11958.000000  11958.000000  11958.000000  11958.000000
# mean       0.104794      0.062891      0.008320      0.000271     62.352617
# std        0.429413      0.561603      0.405100      0.261230    178.247010
# min       -4.781606     -1.338556     -7.976100     -3.575312      0.000000
# 25%       -0.144092     -0.353864     -0.080064     -0.015461      5.000000
# 50%        0.143136      0.001972     -0.003039      0.015452     15.950000
# 75%        0.380076      0.409231      0.106344      0.073171     50.000000
# max        5.525093      3.517346      8.254376      4.860769   7712.430000
#
#               Class
# count  11958.000000
# mean       0.004349
# std        0.065803
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 31 columns]

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
df.dtypes
# Out:
# Time        int64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class     float64
# dtype: object

# %%
sns.countplot(x='Class', data=df, palette='CMRmap')
print('Non-fraud transactions: {}%'.format(round(df.Class.value_counts()[0]/len(df)*100.0,2)))
print('Fraud transactions: {}%'.format(round(df.Class.value_counts()[1]/len(df)*100.0,2)))
# Out:
# Non-fraud transactions: 99.56%
# Fraud transactions: 0.43%

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
ax1 = sns.distplot(df['Time'], ax=ax1, color='y')
ax2 = sns.distplot(df['Amount'], ax=ax2, color='r')
ax1.set_title('Distribution of Time', fontsize=13)
ax2.set_title('Distribution of Amount', fontsize=13)
# Out:
# Text(0.5, 1.0, 'Distribution of Amount')

# %%
from sklearn.preprocessing import RobustScaler
rs = RobustScaler()
df['scaled_amount'] = rs.fit_transform(df['Amount'].values.reshape(-1,1))
df['scaled_time'] = rs.fit_transform(df['Time'].values.reshape(-1,1))
df.drop(['Time', 'Amount'], axis=1, inplace=True)

# %%
scaled_amount = df['scaled_amount']
scaled_time = df['scaled_time']
df.drop(['scaled_amount', 'scaled_time'], axis=1, inplace=True)
df.insert(0, 'scaled_amount', scaled_amount)
df.insert(0, 'scaled_time', scaled_time)
df.head()
# Out:
#    scaled_time  scaled_amount        V1        V2        V3        V4  \
# 0    -0.677033       2.970444 -1.359807 -0.072781  2.536347  1.378155
# 1    -0.677033      -0.294667  1.191857  0.266151  0.166480  0.448154
# 2    -0.676931       8.060222 -1.358354 -1.340163  1.773209  0.379780
# 3    -0.676931       2.390000 -0.966272 -0.185226  1.792993 -0.863291
# 4    -0.676829       1.200889 -1.158233  0.877737  1.548718  0.403034
#
#          V5        V6        V7        V8  ...       V20       V21       V22  \
# 0 -0.338321  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838
# 1  0.060018 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672
# 2 -0.503198  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679
# 3 -0.010309  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274
# 4 -0.407193  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278
#
#         V23       V24       V25       V26       V27       V28  Class
# 0 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053    0.0
# 1  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    0.0
# 2  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752    0.0
# 3 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458    0.0
# 4 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153    0.0
#
# [5 rows x 31 columns]

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split as holdout
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    precision_score,
    recall_score,
    accuracy_score,
)

# Assuming df is already defined
# Separate features (x) and target (y)
x = np.array(df.iloc[:, df.columns != 'Class'])
y = np.array(df.iloc[:, df.columns == 'Class'])

# Handle missing values in x
imputer_x = SimpleImputer(strategy='mean')  # Replace NaN in features with the mean
x = imputer_x.fit_transform(x)

# Handle missing values in y
imputer_y = SimpleImputer(strategy='most_frequent')  # Replace NaN in target with the most common value
y = imputer_y.fit_transform(y)

# Split data into training and testing sets
x_train, x_test, y_train, y_test = holdout(x, y, test_size=0.2, random_state=0)

# Logistic Regression
logreg = LogisticRegression()
logreg.fit(x_train, y_train.ravel())  # Flatten y_train for compatibility
y_pred = logreg.predict(x_test)

# Confusion Matrix
cnf_matrix = confusion_matrix(y_test, y_pred)

# Plot Confusion Matrix
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
labels = ['Non-fraud', 'Fraud']
print(classification_report(y_test, y_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#    Non-fraud       1.00      1.00      1.00      2381
#        Fraud       1.00      0.73      0.84        11
#
#     accuracy                           1.00      2392
#    macro avg       1.00      0.86      0.92      2392
# weighted avg       1.00      1.00      1.00      2392

# %%
from imblearn.over_sampling import SMOTE
import seaborn as sns
import matplotlib.pyplot as plt

# Print the shape of the datasets
print("Transaction Number x_train dataset: ", x_train.shape)
print("Transaction Number y_train dataset: ", y_train.shape)
print("Transaction Number x_test dataset: ", x_test.shape)
print("Transaction Number y_test dataset: ", y_test.shape)

# Print the class distribution before SMOTE
print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0)))

# Apply SMOTE to oversample the minority class in the training data
sm = SMOTE(random_state=2)
x_train_s, y_train_s = sm.fit_resample(x_train, y_train.ravel())  # Using fit_resample instead of fit_sample

# Print the shape of the resampled training data
print('After OverSampling, the shape of train_x: {}'.format(x_train_s.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_s.shape))

# Print the class distribution after SMOTE
print("After OverSampling, counts of label '1', %: {:.2f}".format(sum(y_train_s == 1) / len(y_train_s) * 100.0))
print("After OverSampling, counts of label '0', %: {:.2f}".format(sum(y_train_s == 0) / len(y_train_s) * 100.0))

# Plot the class distribution after oversampling
sns.countplot(x=y_train_s, palette='CMRmap')
plt.title('Class Distribution After SMOTE')
plt.show()
# Out:
# Transaction Number x_train dataset:  (9567, 30)
# Transaction Number y_train dataset:  (9567, 1)
# Transaction Number x_test dataset:  (2392, 30)
# Transaction Number y_test dataset:  (2392, 1)
# Before OverSampling, counts of label '1': [41]
# Before OverSampling, counts of label '0': [9526]
#
# After OverSampling, the shape of train_x: (19052, 30)
# After OverSampling, the shape of train_y: (19052,)
#
# After OverSampling, counts of label '1', %: 50.00
# After OverSampling, counts of label '0', %: 50.00

# %% [markdown]
# **Logistic Regression with SMOTE**

# %%
logreg = LogisticRegression()
logreg.fit(x_train_s, y_train_s)
y_pred = logreg.predict(x_test)
cnf_matrix = confusion_matrix(y_test, y_pred)

sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      1.00      2381
#          1.0       0.38      0.91      0.54        11
#
#     accuracy                           0.99      2392
#    macro avg       0.69      0.95      0.77      2392
# weighted avg       1.00      0.99      0.99      2392

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

# Assuming you already have logreg, x_test, and y_test defined
y_pred_prob = logreg.predict_proba(x_test)[:, 1]
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)

plt.plot(recall, precision)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# **Random Forest Classifier with SMOTE**

# %%
from sklearn.ensemble import RandomForestClassifier as rfc
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Create the Random Forest Classifier model
rand_f = rfc(n_estimators=1000, min_samples_split=10, min_samples_leaf=1,
             max_features='sqrt',  # Use 'sqrt' for classification tasks
             max_leaf_nodes=None,
             oob_score=True, n_jobs=-1, random_state=1)

# Fit the model on the resampled training data
rand_f.fit(x_train_s, y_train_s)

# Predict on the test data
y_pred = rand_f.predict(x_test)

# Generate confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
plt.show()

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2381
#          1.0       0.91      0.91      0.91        11
#
#     accuracy                           1.00      2392
#    macro avg       0.95      0.95      0.95      2392
# weighted avg       1.00      1.00      1.00      2392

# %%
y_pred_prob = rand_f.predict_proba(x_test)[:,1]
precision, recall, thresholds = precision_recall_curve(y_test, y_pred_prob)
plt.plot(precision, recall)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision Recall Curve')
# Out:
# Text(0.5, 1.0, 'Precision Recall Curve')

# %%
#Plotting Feature Importances
print('Feature importance ranking\n\n')
importances = rand_f.feature_importances_
std = np.std([tree.feature_importances_ for tree in rand_f.estimators_],axis=0)
indices = np.argsort(importances)[::-1]
variables = df.columns
importance_list = []
for f in range(x.shape[1]):
    variable = variables[indices[f]]
    importance_list.append(variable)
    print("%d.%s(%f)" % (f + 1, variable, importances[indices[f]]))
plt.figure(figsize=(20, 8))
plt.title("Feature importances")
plt.bar(importance_list, importances[indices],
       color="purple", yerr=std[indices], align='center')
# Out:
# Feature importance ranking
#
#
# 1.V12(0.170585)
# 2.V4(0.144965)
# 3.V14(0.142243)
# 4.V3(0.085944)
# 5.V11(0.080104)
# 6.V10(0.073829)
# 7.V2(0.055346)
# 8.V17(0.050594)
# 9.V6(0.033352)
# 10.V16(0.027023)
# 11.V7(0.024370)
# 12.V9(0.017019)
# 13.V19(0.013629)
# 14.V27(0.013200)
# 15.scaled_time(0.009182)
# 16.V5(0.007898)
# 17.V20(0.007715)
# 18.V21(0.005950)
# 19.scaled_amount(0.005916)
# 20.V18(0.004306)
# 21.V26(0.003746)
# 22.V13(0.003725)
# 23.V1(0.003461)
# 24.V8(0.003012)
# 25.V15(0.002797)
# 26.V23(0.002690)
# 27.V28(0.002667)
# 28.V24(0.002181)
# 29.V22(0.001463)
# 30.V25(0.001087)
# <BarContainer object of 30 artists>

# %% [markdown]
# **XGBoost**

# %%
import xgboost as xgb
model = xgb.XGBClassifier(n_estimators = 5000, max_depth = 30, learning_rate = 0.01)
model.fit(x_train_s, y_train_s)
y_pred = model.predict(x_test)

cnf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2381
#          1.0       1.00      0.91      0.95        11
#
#     accuracy                           1.00      2392
#    macro avg       1.00      0.95      0.98      2392
# weighted avg       1.00      1.00      1.00      2392

# %% [markdown]
# Neural **Network**

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
model = Sequential([Dense(input_dim=30, units=16, activation='relu'),
                   Dense(units=24, activation='relu'),
                   Dropout(0.5),
                   Dense(units=20, activation='relu'),
                   Dense(units=24, activation='relu'),
                   Dense(units=1, activation='sigmoid')])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │             496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 24)                  │             408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 24)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 20)                  │             500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 24)                  │             504 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              25 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,933 (7.55 KB)
#  Trainable params: 1,933 (7.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x_train_s, y_train_s, batch_size=15, epochs=15)
# Out:
# Epoch 1/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9206 - loss: 0.1898
# Epoch 2/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9969 - loss: 0.0133
# Epoch 3/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9985 - loss: 0.0098
# Epoch 4/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9987 - loss: 0.0075
# Epoch 5/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9992 - loss: 0.0060
# Epoch 6/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9991 - loss: 0.0050
# Epoch 7/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9995 - loss: 0.0035
# Epoch 8/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9990 - loss: 0.0053
# Epoch 9/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9994 - loss: 0.0042
# Epoch 10/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9997 - loss: 0.0032
# Epoch 11/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9994 - loss: 0.0054
# Epoch 12/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9997 - loss: 0.0031
# Epoch 13/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9995 - loss: 0.0022
# Epoch 14/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9997 - loss: 0.0021
# Epoch 15/15
# 1271/1271 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9994 - loss: 0.0035

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <Axes: >

# %%
score = model.evaluate(x_test, y_test)
print(score)
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0756
# [0.11662586033344269, 0.9991638660430908]

# %%
# Create the Random Forest Classifier model
rand_f = rfc(n_estimators=1000, min_samples_split=10, min_samples_leaf=1,
             max_features='sqrt',  # Use 'sqrt' for classification tasks
             max_leaf_nodes=None,
             oob_score=True, n_jobs=-1, random_state=1)

# Fit the model on the resampled training data
rand_f.fit(x_train_s, y_train_s)

# Predict on the test data
y_pred = rand_f.predict(x_test)

# Generate confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.title('Confusion Matrix')
plt.show()

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2381
#          1.0       0.91      0.91      0.91        11
#
#     accuracy                           1.00      2392
#    macro avg       0.95      0.95      0.95      2392
# weighted avg       1.00      1.00      1.00      2392
